# %%
import torch
import torchvision
from torchvision import transforms, datasets

# %%
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.1307,), (0.3081,)) # Mean and standard deviation for MNIST
])

# %%
train_dataset = datasets.MNIST(root='../data', train=True, download=False, transform=transform)
test_dataset = datasets.MNIST(root='../data', train=False, download=False, transform=transform)

# %%
train_dataset.data.shape
# Out:
# torch.Size([60000, 28, 28])

# %%
from matplotlib import pyplot as plt
import random
idx = random.randint(0, len(train_dataset)-1)
print(f"Image Shape: {train_dataset.data[idx].shape}")
print(f"Range: {[train_dataset.data[idx].min(),train_dataset.data[idx].max()]}")
plt.imshow(train_dataset.data[idx], cmap='gray')
# Out:
# Image Shape: torch.Size([28, 28])
# Negative elements: 0
# Range: [tensor(0, dtype=torch.uint8), tensor(255, dtype=torch.uint8)]
